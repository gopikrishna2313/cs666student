# %% [markdown]
# <a href="https://colab.research.google.com/github/gopikrishna2313/cs666student/blob/main/Copy_of_CS666_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo.png](data:image/png;base64,...)
#
# # Assignment 1

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Task 1** (5 pts): Install the BioSPPY library with the following code.

# %%
# !pip install biosppy
# Out:
# Requirement already satisfied: biosppy in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: bidict in /usr/local/lib/python3.10/dist-packages (from biosppy) (0.22.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from biosppy) (3.9.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from biosppy) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biosppy) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from biosppy) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from biosppy) (1.11.4)
# Requirement already satisfied: shortuuid in /usr/local/lib/python3.10/dist-packages (from biosppy) (1.0.11)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from biosppy) (1.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from biosppy) (1.3.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from biosppy) (4.8.0.76)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.10/dist-packages (from biosppy) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosppy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosppy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosppy) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosppy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosppy) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosppy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosppy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosppy) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->biosppy) (3.2.0)

# %% [markdown]
# **Task 2** (10 pts): Download a sample ecg dataset from https://cs666.org/data/ecg.txt and upload it to this colab. The following code loads the dataset.

# %%
from biosppy import storage
signal, metadata = storage.load_txt('/ecg.txt')

# %% [markdown]
# **Task 3** (10 pts): Figure out the sampling rate for this data and how many seconds it lasts.

# %%
SAMPLING_RATE = metadata['sampling_rate']
SECONDS = len(signal) / SAMPLING_RATE

# %% [markdown]
# **Task 4** (15 pts): Process the signal with BioSPPY using the `ecg.ecg` method.

# %%
from biosppy import signals
out = signals.ecg.ecg(signal=signal, sampling_rate=SAMPLING_RATE, show=False)

# %% [markdown]
# **Task 5** (10 pts): Plot the first 3 seconds of the unfiltered signal and then the filtered signal. Can you spot the P, Q, R, S, T waves?

# %%
import matplotlib.pyplot as plt

# %%
# Plot the first 3 seconds of the unfiltered signal
plt.figure()
plt.plot(signal[:int(3 * SAMPLING_RATE)])
plt.title('Unfiltered ECG Signal (First 3 Seconds)')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
# Plot the first 3 seconds of the filtered signal
plt.figure()
plt.plot(out['filtered'][:int(3 * SAMPLING_RATE)])
plt.title('Filtered ECG Signal (First 3 Seconds)')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# **Task 6** (15 pts): Please plot the whole filtered signal and mark the r-peaks with vertical lines based on the ecg.ecg output. You can use `plt.axvline(x = 100, color = 'r', ls=':')` to create a red, dashed vertical line at position 100. Please label the x-axis as 'time [s]'.

# %%
time = [i / SAMPLING_RATE for i in range(len(signal))]

# Plot the filtered signal
plt.figure()
plt.plot(time, out['filtered'])
plt.title('Filtered ECG Signal')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')

rpeaks = out['rpeaks']
for r_peak in rpeaks:
    plt.axvline(x=r_peak / SAMPLING_RATE, color='r', ls=':')

plt.show()

# %% [markdown]
# **Task 7** (5 pts): Let's install the NeuroKit2 library.

# %%
# !pip install neurokit2
import neurokit2 as nk
# Out:
# Requirement already satisfied: neurokit2 in /usr/local/lib/python3.10/dist-packages (0.2.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from neurokit2) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from neurokit2) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from neurokit2) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from neurokit2) (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from neurokit2) (3.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->neurokit2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->neurokit2) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurokit2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurokit2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurokit2) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurokit2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurokit2) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurokit2) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurokit2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurokit2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->neurokit2) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->neurokit2) (1.16.0)

# %% [markdown]
# **Task 8** (20 pts): Detect P Q S T Peaks using Neurokit.

# %%
_, waves_peak = nk.ecg_delineate(signal,
                                 out['rpeaks'],
                                 sampling_rate=SAMPLING_RATE,
                                 method="peak",
                                 show=True,
                                 show_type='peaks')

# %%
#Does the detection work well?

# %% [markdown]
# Yes

# %% [markdown]
# **Task 9** (10 pts): Use the sleepecg library to find the R Peaks.

# %%
# We have the R spikes/peaks now from Biosppy from above but there is another
# library called sleepecg.
# TODO Please install it and run the rpeak detection!
# Docs: https://sleepecg.readthedocs.io/en/stable/
# !pip install sleepecg
from sleepecg import detect_heartbeats
rpeaks_sleepecg = detect_heartbeats(signal,SAMPLING_RATE)
time = [i / SAMPLING_RATE for i in range(len(signal))]

# Plot the signal
plt.figure()
plt.plot(time, signal, label='ECG Signal')
plt.title('ECG Signal with Detected Heartbeats')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')

# Plot vertical lines at the R-peak locations
for r_peak in rpeaks_sleepecg:
    plt.axvline(x=r_peak / SAMPLING_RATE, color='r', ls=':')

plt.legend()
plt.show()
# Out:
# Requirement already satisfied: sleepecg in /usr/local/lib/python3.10/dist-packages (0.5.7)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from sleepecg) (1.25.2)
# Requirement already satisfied: PyYAML>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from sleepecg) (6.0.1)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from sleepecg) (2.31.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from sleepecg) (1.11.4)
# Requirement already satisfied: tqdm>=4.60.0 in /usr/local/lib/python3.10/dist-packages (from sleepecg) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sleepecg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sleepecg) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sleepecg) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sleepecg) (2024.2.2)

# %%
# TODO Do Biosppy and sleepecg give different rpeaks? Please calculate the MSE!
from sklearn.metrics import mean_squared_error
print(mean_squared_error(rpeaks,rpeaks_sleepecg))
# Out:
# 0.2

# %% [markdown]
# MSE is 0.2 so there might be small difference

# %% [markdown]
# **Bonus Task** (33 pts): Detect P Q S T Peaks for the full signal before and after filtering.

# %%
signal_filtered = out['filtered']
_, peaks_filtered = nk.ecg_delineate(signal_filtered, out['rpeaks'], sampling_rate=SAMPLING_RATE, method='peak', show_type='peaks', show=True)

plot = nk.events_plot([peaks_filtered['ECG_T_Peaks'][:],
                       peaks_filtered['ECG_P_Peaks'][:],
                       peaks_filtered['ECG_Q_Peaks'][:],
                       peaks_filtered['ECG_S_Peaks'][:]], signal_filtered)

# %%
import numpy as np
import neurokit2 as nk

rpeaks = out["rpeaks"]

# Filter the signal
lowcut = 5
highcut = 15
signal_filtered = nk.signal_filter(signal, lowcut=lowcut, highcut=highcut, sampling_rate=SAMPLING_RATE, order=3)

# Detect P Q S T peaks for filtered signal
_, peaks_filtered = nk.ecg_delineate(signal_filtered, rpeaks, sampling_rate=SAMPLING_RATE, method='peak', show=True)

# %%
# Finally, run the delineation on the filtered signal from BioSPPY.

# %%
# TODO Which one works the best?
#--- ECG_P_PEAKS

# %%
#
# Great job!!
#
#  , ; ,   .-'"""'-.   , ; ,
#  \\|/  .'         '.  \|//
#   \-;-/   ()   ()   \-;-/
#   // ;               ; \\
#  //__; :.         .; ;__\\
# `-----\'.'-.....-'.'/-----'
#        '.'.-.-,_.'.'
#jgs       '(  (..-'
#            '-'
#
